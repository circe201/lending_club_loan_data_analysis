# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./input/lending-club-loan-data/loan1.csv', low_memory=False)
data.head()
# Out:
#    Unnamed: 0  id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      200001 NaN        NaN      20000        20000          20000.0
# 1      200002 NaN        NaN      10000        10000           9725.0
# 2      200003 NaN        NaN      40000        40000          40000.0
# 3      200004 NaN        NaN       5000         5000           5000.0
# 4      200005 NaN        NaN      14000        14000          14000.0
#
#          term  int_rate  installment grade  ...  \
# 0   60 months     12.73       452.31     B  ...
# 1   36 months     12.73       335.65     B  ...
# 2   36 months      8.46      1261.97     A  ...
# 3   36 months      6.67       153.64     A  ...
# 4   36 months      8.46       441.69     A  ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method debt_settlement_flag  debt_settlement_flag_date  \
# 0                Cash                    N                        NaN
# 1                Cash                    N                        NaN
# 2                Cash                    N                        NaN
# 3                Cash                    N                        NaN
# 4                Cash                    N                        NaN
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0               NaN             NaN               NaN                   NaN
# 1               NaN             NaN               NaN                   NaN
# 2               NaN             NaN               NaN                   NaN
# 3               NaN             NaN               NaN                   NaN
# 4               NaN             NaN               NaN                   NaN
#
#    settlement_term
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 146 columns]

# %%
# print number of features and shape of data
records = data.shape[0]
print ('Number of records is ',records)
print ('Number of features is ',len(data.columns))
# Out:
# Number of records is  199999
# Number of features is  146

# %% [markdown]
# ### Missing Attributes in Data
#
#     - We find that there lot of attributes which have completely missing values - removing those.

# %%
def missing_zero_values_table(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
        mz_table['Total Zero Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
        mz_table['% Total Zero Missing Values'] = 100 * mz_table['Total Zero Missing Values'] / len(df)
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
#         mz_table.to_excel('D:/sampledata/missing_and_zero_values.xlsx', freeze_panes=(1,0), index = False)
        return mz_table

missing_zero_values_table(data)
# Out:
# Your selected dataframe has 146 columns and 199999 Rows.
# There are 62 columns that have missing values.
#                                             Zero Values  Missing Values  \
# id                                                    0          199999
# url                                                   0          199999
# member_id                                             0          199999
# desc                                                  0          199999
# orig_projected_additional_accrued_interest            0          199927
# hardship_length                                       0          199920
# payment_plan_start_date                               0          199920
# hardship_reason                                       0          199920
# hardship_status                                       0          199920
# deferral_term                                         0          199920
# hardship_amount                                       0          199920
# hardship_start_date                                   0          199920
# hardship_end_date                                     0          199920
# hardship_type                                         0          199920
# hardship_dpd                                         31          199920
# hardship_loan_status                                  0          199920
# hardship_payoff_balance_amount                        0          199920
# hardship_last_payment_amount                          0          199920
# settlement_date                                       0          199840
# settlement_percentage                                 0          199840
# debt_settlement_flag_date                             0          199840
# settlement_status                                     0          199840
# settlement_amount                                     0          199840
# settlement_term                                       0          199840
# sec_app_mths_since_last_major_derog                 101          190695
# mths_since_last_record                                0          174796
# verification_status_joint                             0          173797
# sec_app_revol_util                                  335          172829
# sec_app_open_acc                                     21          172339
# annual_inc_joint                                      0          172339
# ...                                                 ...             ...
# sec_app_chargeoff_within_12_mths                  26989          172339
# sec_app_open_act_il                                3681          172339
# revol_bal_joint                                      30          172339
# sec_app_mort_acc                                  11082          172339
# sec_app_inq_last_6mths                            16885          172339
# sec_app_num_rev_accts                               175          172339
# sec_app_earliest_cr_line                              0          172339
# mths_since_recent_bc_dlq                              0          159874
# mths_since_last_major_derog                           3          152535
# mths_since_recent_revol_delinq                        0          141739
# mths_since_last_delinq                                0          110586
# il_util                                             500           33178
# mths_since_recent_inq                             13957           24079
# next_pymnt_d                                          0           22052
# emp_title                                             0           16539
# emp_length                                            0           15805
# mo_sin_old_il_acct                                    0            7559
# mths_since_rcnt_il                                   93            7559
# num_tl_120dpd_2m                                 195461            4538
# bc_util                                            4067            2727
# percent_bc_gt_75                                  76999            2650
# bc_open_to_buy                                     1269            2647
# mths_since_recent_bc                               1388            2490
# dti                                                 360             508
# last_pymnt_d                                          0             271
# revol_util                                         2090             227
# all_util                                            683              50
# avg_cur_bal                                         247              12
# last_credit_pull_d                                    0               3
# pct_tl_nvr_dlq                                        1               1
#
#                                             % of Total Values  \
# id                                                      100.0
# url                                                     100.0
# member_id                                               100.0
# desc                                                    100.0
# orig_projected_additional_accrued_interest              100.0
# hardship_length                                         100.0
# payment_plan_start_date                                 100.0
# hardship_reason                                         100.0
# hardship_status                                         100.0
# deferral_term                                           100.0
# hardship_amount                                         100.0
# hardship_start_date                                     100.0
# hardship_end_date                                       100.0
# hardship_type                                           100.0
# hardship_dpd                                            100.0
# hardship_loan_status                                    100.0
# hardship_payoff_balance_amount                          100.0
# hardship_last_payment_amount                            100.0
# settlement_date                                          99.9
# settlement_percentage                                    99.9
# debt_settlement_flag_date                                99.9
# settlement_status                                        99.9
# settlement_amount                                        99.9
# settlement_term                                          99.9
# sec_app_mths_since_last_major_derog                      95.3
# mths_since_last_record                                   87.4
# verification_status_joint                                86.9
# sec_app_revol_util                                       86.4
# sec_app_open_acc                                         86.2
# annual_inc_joint                                         86.2
# ...                                                       ...
# sec_app_chargeoff_within_12_mths                         86.2
# sec_app_open_act_il                                      86.2
# revol_bal_joint                                          86.2
# sec_app_mort_acc                                         86.2
# sec_app_inq_last_6mths                                   86.2
# sec_app_num_rev_accts                                    86.2
# sec_app_earliest_cr_line                                 86.2
# mths_since_recent_bc_dlq                                 79.9
# mths_since_last_major_derog                              76.3
# mths_since_recent_revol_delinq                           70.9
# mths_since_last_delinq                                   55.3
# il_util                                                  16.6
# mths_since_recent_inq                                    12.0
# next_pymnt_d                                             11.0
# emp_title                                                 8.3
# emp_length                                                7.9
# mo_sin_old_il_acct                                        3.8
# mths_since_rcnt_il                                        3.8
# num_tl_120dpd_2m                                          2.3
# bc_util                                                   1.4
# percent_bc_gt_75                                          1.3
# bc_open_to_buy                                            1.3
# mths_since_recent_bc                                      1.2
# dti                                                       0.3
# last_pymnt_d                                              0.1
# revol_util                                                0.1
# all_util                                                  0.0
# avg_cur_bal                                               0.0
# last_credit_pull_d                                        0.0
# pct_tl_nvr_dlq                                            0.0
#
#                                             Total Zero Missing Values  \
# id                                                             199999
# url                                                            199999
# member_id                                                      199999
# desc                                                           199999
# orig_projected_additional_accrued_interest                     199927
# hardship_length                                                199920
# payment_plan_start_date                                        199920
# hardship_reason                                                199920
# hardship_status                                                199920
# deferral_term                                                  199920
# hardship_amount                                                199920
# hardship_start_date                                            199920
# hardship_end_date                                              199920
# hardship_type                                                  199920
# hardship_dpd                                                   199951
# hardship_loan_status                                           199920
# hardship_payoff_balance_amount                                 199920
# hardship_last_payment_amount                                   199920
# settlement_date                                                199840
# settlement_percentage                                          199840
# debt_settlement_flag_date                                      199840
# settlement_status                                              199840
# settlement_amount                                              199840
# settlement_term                                                199840
# sec_app_mths_since_last_major_derog                            190796
# mths_since_last_record                                         174796
# verification_status_joint                                      173797
# sec_app_revol_util                                             173164
# sec_app_open_acc                                               172360
# annual_inc_joint                                               172339
# ...                                                               ...
# sec_app_chargeoff_within_12_mths                               199328
# sec_app_open_act_il                                            176020
# revol_bal_joint                                                172369
# sec_app_mort_acc                                               183421
# sec_app_inq_last_6mths                                         189224
# sec_app_num_rev_accts                                          172514
# sec_app_earliest_cr_line                                       172339
# mths_since_recent_bc_dlq                                       159874
# mths_since_last_major_derog                                    152538
# mths_since_recent_revol_delinq                                 141739
# mths_since_last_delinq                                         110586
# il_util                                                         33678
# mths_since_recent_inq                                           38036
# next_pymnt_d                                                    22052
# emp_title                                                       16539
# emp_length                                                      15805
# mo_sin_old_il_acct                                               7559
# mths_since_rcnt_il                                               7652
# num_tl_120dpd_2m                                               199999
# bc_util                                                          6794
# percent_bc_gt_75                                                79649
# bc_open_to_buy                                                   3916
# mths_since_recent_bc                                             3878
# dti                                                               868
# last_pymnt_d                                                      271
# revol_util                                                       2317
# all_util                                                          733
# avg_cur_bal                                                       259
# last_credit_pull_d                                                  3
# pct_tl_nvr_dlq                                                      2
#
#                                             % Total Zero Missing Values  \
# id                                                                100.0
# url                                                               100.0
# member_id                                                         100.0
# desc                                                              100.0
# orig_projected_additional_accrued_interest                        100.0
# hardship_length                                                   100.0
# payment_plan_start_date                                           100.0
# hardship_reason                                                   100.0
# hardship_status                                                   100.0
# deferral_term                                                     100.0
# hardship_amount                                                   100.0
# hardship_start_date                                               100.0
# hardship_end_date                                                 100.0
# hardship_type                                                     100.0
# hardship_dpd                                                      100.0
# hardship_loan_status                                              100.0
# hardship_payoff_balance_amount                                    100.0
# hardship_last_payment_amount                                      100.0
# settlement_date                                                    99.9
# settlement_percentage                                              99.9
# debt_settlement_flag_date                                          99.9
# settlement_status                                                  99.9
# settlement_amount                                                  99.9
# settlement_term                                                    99.9
# sec_app_mths_since_last_major_derog                                95.4
# mths_since_last_record                                             87.4
# verification_status_joint                                          86.9
# sec_app_revol_util                                                 86.6
# sec_app_open_acc                                                   86.2
# annual_inc_joint                                                   86.2
# ...                                                                 ...
# sec_app_chargeoff_within_12_mths                                   99.7
# sec_app_open_act_il                                                88.0
# revol_bal_joint                                                    86.2
# sec_app_mort_acc                                                   91.7
# sec_app_inq_last_6mths                                             94.6
# sec_app_num_rev_accts                                              86.3
# sec_app_earliest_cr_line                                           86.2
# mths_since_recent_bc_dlq                                           79.9
# mths_since_last_major_derog                                        76.3
# mths_since_recent_revol_delinq                                     70.9
# mths_since_last_delinq                                             55.3
# il_util                                                            16.8
# mths_since_recent_inq                                              19.0
# next_pymnt_d                                                       11.0
# emp_title                                                           8.3
# emp_length                                                          7.9
# mo_sin_old_il_acct                                                  3.8
# mths_since_rcnt_il                                                  3.8
# num_tl_120dpd_2m                                                  100.0
# bc_util                                                             3.4
# percent_bc_gt_75                                                   39.8
# bc_open_to_buy                                                      2.0
# mths_since_recent_bc                                                1.9
# dti                                                                 0.4
# last_pymnt_d                                                        0.1
# revol_util                                                          1.2
# all_util                                                            0.4
# avg_cur_bal                                                         0.1
# last_credit_pull_d                                                  0.0
# pct_tl_nvr_dlq                                                      0.0
#
#                                            Data Type
# id                                           float64
# url                                          float64
# member_id                                    float64
# desc                                         float64
# orig_projected_additional_accrued_interest   float64
# hardship_length                              float64
# payment_plan_start_date                       object
# hardship_reason                               object
# hardship_status                               object
# deferral_term                                float64
# hardship_amount                              float64
# hardship_start_date                           object
# hardship_end_date                             object
# hardship_type                                 object
# hardship_dpd                                 float64
# hardship_loan_status                          object
# hardship_payoff_balance_amount               float64
# hardship_last_payment_amount                 float64
# settlement_date                               object
# settlement_percentage                        float64
# debt_settlement_flag_date                     object
# settlement_status                             object
# settlement_amount                            float64
# settlement_term                              float64
# sec_app_mths_since_last_major_derog          float64
# mths_since_last_record                       float64
# verification_status_joint                     object
# sec_app_revol_util                           float64
# sec_app_open_acc                             float64
# annual_inc_joint                             float64
# ...                                              ...
# sec_app_chargeoff_within_12_mths             float64
# sec_app_open_act_il                          float64
# revol_bal_joint                              float64
# sec_app_mort_acc                             float64
# sec_app_inq_last_6mths                       float64
# sec_app_num_rev_accts                        float64
# sec_app_earliest_cr_line                      object
# mths_since_recent_bc_dlq                     float64
# mths_since_last_major_derog                  float64
# mths_since_recent_revol_delinq               float64
# mths_since_last_delinq                       float64
# il_util                                      float64
# mths_since_recent_inq                        float64
# next_pymnt_d                                  object
# emp_title                                     object
# emp_length                                    object
# mo_sin_old_il_acct                           float64
# mths_since_rcnt_il                           float64
# num_tl_120dpd_2m                             float64
# bc_util                                      float64
# percent_bc_gt_75                             float64
# bc_open_to_buy                               float64
# mths_since_recent_bc                         float64
# dti                                          float64
# last_pymnt_d                                  object
# revol_util                                   float64
# all_util                                     float64
# avg_cur_bal                                  float64
# last_credit_pull_d                            object
# pct_tl_nvr_dlq                               float64
#
# [62 rows x 6 columns]

# %%
data = data.dropna(axis=1, how='any')

# print number of features and shape of data
print ('Number of records is ',data.shape[0])
print ('Number of features is ',len(data.columns))

data.to_csv('./input/lending-club-loan-data/clean_loan.csv')
# Out:
# Number of records is  199999
# Number of features is  84

# %%
data.head()
# Out:
#    Unnamed: 0  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0      200001      20000        20000          20000.0   60 months     12.73
# 1      200002      10000        10000           9725.0   36 months     12.73
# 2      200003      40000        40000          40000.0   36 months      8.46
# 3      200004       5000         5000           5000.0   36 months      6.67
# 4      200005      14000        14000          14000.0   36 months      8.46
#
#    installment grade sub_grade home_ownership  ...  num_tl_op_past_12m  \
# 0       452.31     B        B5           RENT  ...                 0.0
# 1       335.65     B        B5           RENT  ...                 1.0
# 2      1261.97     A        A5       MORTGAGE  ...                 2.0
# 3       153.64     A        A2       MORTGAGE  ...                 1.0
# 4       441.69     A        A5           RENT  ...                 0.0
#
#   pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 0                  0.0       0.0         17100.0            7428.0
# 1                  0.0       0.0         26394.0           17904.0
# 2                  0.0       0.0        376496.0           75188.0
# 3                  0.0       0.0         44644.0           13269.0
# 4                  0.0       0.0         19400.0           12902.0
#
#   total_bc_limit total_il_high_credit_limit hardship_flag disbursement_method  \
# 0        13500.0                        0.0             N                Cash
# 1        11000.0                    15394.0             N                Cash
# 2        60400.0                    77310.0             N                Cash
# 3        15300.0                    14244.0             N                Cash
# 4         8100.0                    10000.0             N                Cash
#
#    debt_settlement_flag
# 0                     N
# 1                     N
# 2                     N
# 3                     N
# 4                     N
#
# [5 rows x 84 columns]

# %%
import gc
gc.collect()
# Out:
# 88
